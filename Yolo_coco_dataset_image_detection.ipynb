# %% [markdown]
# <a href="https://colab.research.google.com/github/v-aguiar/yolov8-image-detection-coco-dataset/blob/main/Yolo_coco_dataset_image_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Utilizando a rede YOLO V8 treinada no dataset do COCO para realizar a detecção de objetos
#
# A rede Yolo V8 já é treinada com mais de 80 classes do COCO, o que facilita bastante o processo de detecção.
# Também é opssível realizar o transfer Learning para treinar o modelo e fazê-lo detectar novas classes.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Instalação da rede YOLOv8

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.2/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## Detecção utilizando o modelo pré treinado com o COCO

# %% [markdown]
# A instrução `yolo mode=predict` do YOLOv8 executa a detecção sem que seja necessário definir um modelo específico. O sistema faz o download do modelo mais adequado automaticamente.
#
# Aqui basta adicionar a URL de qualquer imagem no parâmetro `source` e o modelo irá realizar a detecção. O resultado ficará salvo em `runs/predict`

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://www.shutterstock.com/image-photo/girl-her-cat-dog-260nw-2315168017.jpg' save=True
# Out:
# /content
# ...
# 100% 6.25M/6.25M [00:00<00:00, 122MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 28.0k/28.0k [00:00<00:00, 33.4MB/s]
# image 1/1 /content/girl-her-cat-dog-260nw-2315168017.jpg: 480x640 1 person, 1 cat, 2 dogs, 1 bed, 38.5ms
# Speed: 13.7ms preprocess, 38.5ms inference, 343.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/girl-her-cat-dog-260nw-2315168017.jpg', height=600)
# Out:
# /content
